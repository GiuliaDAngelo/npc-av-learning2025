# %%
import numpy as np
import matplotlib.pyplot as plt

im_recon = "/media/matt/bigdata/DATA/CRIB/resultsbbox30050epochs/reconstructions.png"

# display image inline
im = plt.imread(im_recon)
plt.imshow(im)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()
